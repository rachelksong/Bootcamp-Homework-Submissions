# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#OpenWeatherMapKey
api_key = api_keys.api_key

#Endpoint for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

display(api_key)
# Out:
# 'ab5c9b31ff53585d7f094b4ad41c7e24'

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval from WeatherMap API")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    try: 
        response = requests.get(f"{url}{api_key}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # Skip if no match found
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval from WeatherMap API
# -------------------------------
# Processing Record 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ushuaia
# Processing Record 2 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bluff
# Processing Record 3 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kodiak
# City not found. Skipping...
# Processing Record 4 | Gympie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=gympie
# Processing Record 5 | Crotone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=crotone
# City not found. Skipping...
# Processing Record 6 | Amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=amapa
# Processing Record 7 | Clovis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=clovis
# Processing Record 8 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20lincoln
# Processing Record 9 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20alfred
# Processing Record 10 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=punta%20arenas
# Processing Record 11 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jamestown
# Processing Record 12 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=busselton
# Processing Record 13 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=okhotsk
# Processing Record 14 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=rikitea
# Processing Record 15 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=khatanga
# Processing Record 16 | Taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=taksimo
# Processing Record 17 | Tumut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tumut
# Processing Record 18 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=gizo
# Processing Record 19 | Asasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=asasa
# Processing Record 20 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nouadhibou
# Processing Record 21 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mataura
# Processing Record 22 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=torbay
# Processing Record 23 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kapaa
# Processing Record 24 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=cape%20town
# Processing Record 25 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint%20anthony
# Processing Record 26 | Grand-Santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=grand-santi
# Processing Record 27 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=arraial%20do%20cabo
# Processing Record 28 | Maraa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=maraa
# Processing Record 29 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=upernavik
# Processing Record 30 | Laizhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=laizhou
# Processing Record 31 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=namibe
# City not found. Skipping...
# Processing Record 32 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=srednekolymsk
# City not found. Skipping...
# Processing Record 33 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=albany
# Processing Record 34 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ponta%20do%20sol
# Processing Record 35 | Bang Saphan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bang%20saphan
# Processing Record 36 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=carnarvon
# Processing Record 37 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=geraldton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint-philippe
# Processing Record 39 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nikolskoye
# Processing Record 40 | Road Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=road%20town
# Processing Record 41 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=iqaluit
# Processing Record 42 | Kontagora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kontagora
# Processing Record 43 | Raeren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=raeren
# Processing Record 44 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nanortalik
# Processing Record 45 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=richards%20bay
# Processing Record 46 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hermanus
# Processing Record 47 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hobyo
# Processing Record 48 | Dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dalvik
# Processing Record 49 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yellowknife
# Processing Record 50 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lasa
# Processing Record 51 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=atuona
# Processing Record 52 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=thompson
# Processing Record 53 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=alofi
# Processing Record 54 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saldanha
# Processing Record 55 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vao
# Processing Record 56 | Konakovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=konakovo
# Processing Record 57 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=isangel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 58 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bahia%20blanca
# Processing Record 59 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vaini
# Processing Record 60 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kavieng
# Processing Record 61 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hithadhoo
# Processing Record 62 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=constitucion
# Processing Record 63 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=moron
# Processing Record 64 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=butaritari
# Processing Record 65 | Kundiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kundiawa
# Processing Record 66 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=gat
# Processing Record 67 | Berkakit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=berkakit
# Processing Record 68 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ancud
# Processing Record 69 | Katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=katangli
# Processing Record 70 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pevek
# Processing Record 71 | Vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vanavara
# Processing Record 72 | Oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=oyama
# Processing Record 73 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tiksi
# Processing Record 74 | Vyazma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vyazma
# Processing Record 75 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=omsukchan
# Processing Record 76 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=te%20anau
# Processing Record 77 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chokurdakh
# Processing Record 78 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=barrow
# Processing Record 79 | Phuntsholing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=phuntsholing
# Processing Record 80 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tuktoyaktuk
# Processing Record 81 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pisco
# Processing Record 82 | San Angelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=san%20angelo
# Processing Record 83 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aykhal
# Processing Record 84 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=new%20norfolk
# Processing Record 85 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lorengau
# Processing Record 86 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yulara
# Processing Record 87 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=norman%20wells
# Processing Record 88 | Arys
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=arys
# City not found. Skipping...
# Processing Record 89 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mar%20del%20plata
# City not found. Skipping...
# Processing Record 90 | Hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hun
# Processing Record 91 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=clyde%20river
# City not found. Skipping...
# Processing Record 92 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sorland
# Processing Record 93 | Fairview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=fairview
# Processing Record 94 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=poum
# Processing Record 95 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=haines%20junction
# Processing Record 96 | Chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chabahar
# Processing Record 97 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=souillac
# Processing Record 98 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hilo
# Processing Record 99 | Siteki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=siteki
# Processing Record 100 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aasiaat
# Processing Record 101 | Shiyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=shiyan
# Processing Record 102 | Lahad Datu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lahad%20datu
# City not found. Skipping...
# Processing Record 103 | Aitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aitape
# Processing Record 104 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sur
# Processing Record 105 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bay%20roberts
# City not found. Skipping...
# Processing Record 106 | Prado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=prado
# Processing Record 107 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=narsaq
# Processing Record 108 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hobart
# Processing Record 109 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=los%20llanos%20de%20aridane
# Processing Record 110 | Batsfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=batsfjord
# Processing Record 111 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=udachnyy
# Processing Record 112 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=havre-saint-pierre
# Processing Record 113 | Vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vizinga
# Processing Record 114 | Anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=anloga
# Processing Record 115 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=avarua
# Processing Record 116 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20moresby
# Processing Record 117 | Penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=penzance
# Processing Record 118 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mahebourg
# Processing Record 119 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=luderitz
# Processing Record 120 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kaitangata
# Processing Record 121 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sao%20joao%20da%20barra
# Processing Record 122 | Placido de Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=placido%20de%20castro
# Processing Record 123 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saskylakh
# Processing Record 124 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=qaanaaq
# Processing Record 125 | West Wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=west%20wendover
# Processing Record 126 | Jizan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jizan
# City not found. Skipping...
# Processing Record 127 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=longyearbyen
# Processing Record 128 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=puerto%20ayora
# Processing Record 129 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=avera
# Processing Record 130 | Petatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=petatlan
# Processing Record 131 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=east%20london
# Processing Record 132 | Baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=baghdad
# Processing Record 133 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hasaki
# Processing Record 134 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nome
# Processing Record 135 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kaeo
# Processing Record 136 | Nishiwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nishiwaki
# Processing Record 137 | Uribia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=uribia
# Processing Record 138 | Lao Cai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lao%20cai
# Processing Record 139 | Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sao%20jose%20da%20coroa%20grande
# Processing Record 140 | Galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=galle
# Processing Record 141 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tasiilaq
# Processing Record 142 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=leningradskiy
# Processing Record 143 | Shiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=shiraz
# Processing Record 144 | Minas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=minas
# Processing Record 145 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=cabo%20san%20lucas
# Processing Record 146 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=atar
# Processing Record 147 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=flin%20flon
# Processing Record 148 | Wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=wamba
# Processing Record 149 | Calabozo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=calabozo
# Processing Record 150 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint%20george
# Processing Record 151 | Ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ternate
# City not found. Skipping...
# Processing Record 152 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ribeira%20grande
# City not found. Skipping...
# Processing Record 153 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=faanui
# City not found. Skipping...
# Processing Record 154 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mayo
# City not found. Skipping...
# Processing Record 155 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kruisfontein
# Processing Record 156 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bambanglipuro
# Processing Record 157 | Ribeira Brava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ribeira%20brava
# Processing Record 158 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=banjar
# Processing Record 159 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=henties%20bay
# Processing Record 160 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ballina
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 161 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lebu
# Processing Record 162 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ayan
# Processing Record 163 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=cherskiy
# Processing Record 164 | Alcudia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=alcudia
# Processing Record 165 | Ust-Maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ust-maya
# Processing Record 166 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=matara
# Processing Record 167 | Aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aswan
# Processing Record 168 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ahuimanu
# City not found. Skipping...
# Processing Record 169 | Benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=benghazi
# Processing Record 170 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vardo
# Processing Record 171 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=salalah
# Processing Record 172 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=airai
# Processing Record 173 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pacific%20grove
# Processing Record 174 | San Carlos de Bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=san%20carlos%20de%20bariloche
# Processing Record 175 | Diego de Almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=diego%20de%20almagro
# Processing Record 176 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hervey%20bay
# Processing Record 177 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=georgetown
# Processing Record 178 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=adrar
# Processing Record 179 | Swan Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=swan%20hill
# City not found. Skipping...
# Processing Record 180 | Socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=socorro
# Processing Record 181 | Kuching
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kuching
# Processing Record 182 | Ayia Galini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ayia%20galini
# City not found. Skipping...
# Processing Record 183 | Alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=alexandria
# Processing Record 184 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=noumea
# Processing Record 185 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=caravelas
# Processing Record 186 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ahipara
# Processing Record 187 | Peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=peniche
# Processing Record 188 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=klaksvik
# Processing Record 189 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=meulaboh
# City not found. Skipping...
# Processing Record 190 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=marawi
# Processing Record 191 | Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yarmouth
# Processing Record 192 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hambantota
# Processing Record 193 | Bayevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bayevo
# Processing Record 194 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=egvekinot
# City not found. Skipping...
# Processing Record 195 | Sangre Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sangre%20grande
# Processing Record 196 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aksarka
# Processing Record 197 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=san%20patricio
# Processing Record 198 | Rafai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=rafai
# Processing Record 199 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=provideniya
# City not found. Skipping...
# Processing Record 200 | Lakes Entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lakes%20entrance
# Processing Record 201 | Tamiahua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tamiahua
# Processing Record 202 | Leo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=leo
# Processing Record 203 | Calderitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=calderitas
# Processing Record 204 | Kataysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kataysk
# Processing Record 205 | Upington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=upington
# Processing Record 206 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dikson
# Processing Record 207 | Mayahi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mayahi
# Processing Record 208 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20elizabeth
# Processing Record 209 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=cidreira
# Processing Record 210 | Xai-Xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=xai-xai
# Processing Record 211 | Ifanadiana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ifanadiana
# Processing Record 212 | Ashtabula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ashtabula
# Processing Record 213 | Tarnogskiy Gorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tarnogskiy%20gorodok
# Processing Record 214 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=komsomolskiy
# Processing Record 215 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bethel
# Processing Record 216 | Bembereke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bembereke
# Processing Record 217 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=guerrero%20negro
# City not found. Skipping...
# Processing Record 218 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tuatapere
# Processing Record 219 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nantucket
# Processing Record 220 | Nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nalut
# Processing Record 221 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port-cartier
# Processing Record 222 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=thinadhoo
# Processing Record 223 | Iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=iranshahr
# City not found. Skipping...
# Processing Record 224 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=salinopolis
# Processing Record 225 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jacareacanga
# City not found. Skipping...
# Processing Record 226 | Lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lahaina
# Processing Record 227 | Oum Hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=oum%20hadjer
# Processing Record 228 | Suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=suntar
# Processing Record 229 | Baculin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=baculin
# Processing Record 230 | Amalapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=amalapuram
# Processing Record 231 | Togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=togur
# Processing Record 232 | Lexington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lexington
# City not found. Skipping...
# Processing Record 233 | Shitkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=shitkino
# Processing Record 234 | Erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=erzin
# Processing Record 235 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=westport
# Processing Record 236 | Westminster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=westminster
# Processing Record 237 | Berani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=berani
# Processing Record 238 | Piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=piacabucu
# Processing Record 239 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sao%20filipe
# Processing Record 240 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=muros
# Processing Record 241 | Polovinnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=polovinnoye
# Processing Record 242 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=katsuura
# Processing Record 243 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=taoudenni
# Processing Record 244 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vostok
# Processing Record 245 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nelson%20bay
# Processing Record 246 | Bongor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bongor
# Processing Record 247 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kloulklubed
# Processing Record 248 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=severo-kurilsk
# Processing Record 249 | Houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=houma
# Processing Record 250 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=zyryanka
# Processing Record 251 | Safakulevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=safakulevo
# Processing Record 252 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=alice%20springs
# Processing Record 253 | Caldwell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=caldwell
# Processing Record 254 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bredasdorp
# Processing Record 255 | Paciran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=paciran
# Processing Record 256 | Saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saurimo
# Processing Record 257 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chicama
# Processing Record 258 | Annino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=annino
# City not found. Skipping...
# Processing Record 259 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=husavik
# Processing Record 260 | Snasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=snasa
# City not found. Skipping...
# Processing Record 261 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=seoul
# City not found. Skipping...
# Processing Record 262 | Madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=madang
# Processing Record 263 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=birao
# Processing Record 264 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tiarei
# Processing Record 265 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=castro
# City not found. Skipping...
# Processing Record 266 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mount%20isa
# Processing Record 267 | Requena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=requena
# Processing Record 268 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=shingu
# Processing Record 269 | Birobidzhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=birobidzhan
# Processing Record 270 | Semporna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=semporna
# Processing Record 271 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=alyangula
# Processing Record 272 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=araouane
# Processing Record 273 | Mariental
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mariental
# City not found. Skipping...
# Processing Record 274 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lompoc
# Processing Record 275 | Sazonovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sazonovo
# Processing Record 276 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=esperance
# Processing Record 277 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint-georges
# Processing Record 278 | Mahanoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mahanoro
# City not found. Skipping...
# Processing Record 279 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lavrentiya
# City not found. Skipping...
# Processing Record 280 | Chaumont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chaumont
# City not found. Skipping...
# Processing Record 281 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sitka
# Processing Record 282 | Pryozerne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pryozerne
# Processing Record 283 | Riosucio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=riosucio
# Processing Record 284 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=grindavik
# Processing Record 285 | Rabo de Peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=rabo%20de%20peixe
# Processing Record 286 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=cabedelo
# Processing Record 287 | Slavuta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=slavuta
# Processing Record 288 | Kolondieba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kolondieba
# Processing Record 289 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=quatre%20cocos
# Processing Record 290 | Verkhnyaya Inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=verkhnyaya%20inta
# Processing Record 291 | El Dovio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=el%20dovio
# City not found. Skipping...
# Processing Record 292 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vestmannaeyjar
# City not found. Skipping...
# Processing Record 293 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=san%20vicente
# Processing Record 294 | Pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pangai
# Processing Record 295 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mao
# Processing Record 296 | Burhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=burhar
# Processing Record 297 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=brae
# City not found. Skipping...
# Processing Record 298 | Punta de Bombon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=punta%20de%20bombon
# Processing Record 299 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=san%20andres
# Processing Record 300 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kalmunai
# Processing Record 301 | Riberalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=riberalta
# Processing Record 302 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=antofagasta
# Processing Record 303 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ilulissat
# City not found. Skipping...
# Processing Record 304 | Sofiyivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sofiyivka
# Processing Record 305 | Kyzyl-Suu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kyzyl-suu
# Processing Record 306 | Bastia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bastia
# Processing Record 307 | Winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=winnemucca
# Processing Record 308 | Dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dandong
# Processing Record 309 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint-augustin
# Processing Record 310 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=waingapu
# City not found. Skipping...
# Processing Record 311 | Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tecoanapa
# Processing Record 312 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kavaratti
# Processing Record 313 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=grand%20gaube
# Processing Record 314 | Hryshkivtsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hryshkivtsi
# Processing Record 315 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nabire
# Processing Record 316 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=karratha
# Processing Record 317 | Khon Kaen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=khon%20kaen
# Processing Record 318 | Jawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jawa
# Processing Record 319 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chuy
# Processing Record 320 | Taitung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=taitung
# Processing Record 321 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mackay
# Processing Record 322 | Krasnodon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=krasnodon
# City not found. Skipping...
# Processing Record 323 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=xining
# City not found. Skipping...
# Processing Record 324 | Lugus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lugus
# City not found. Skipping...
# Processing Record 325 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20hardy
# Processing Record 326 | Kamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kamina
# Processing Record 327 | Talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=talaya
# Processing Record 328 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=margate
# Processing Record 329 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ostrovnoy
# Processing Record 330 | Zatoka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=zatoka
# Processing Record 331 | Topolcani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=topolcani
# Processing Record 332 | Sao Miguel do Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sao%20miguel%20do%20araguaia
# Processing Record 333 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bilibino
# Processing Record 334 | Thiruvananthapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=thiruvananthapuram
# Processing Record 335 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=walvis%20bay
# Processing Record 336 | Fereydun Kenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=fereydun%20kenar
# Processing Record 337 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kumluca
# Processing Record 338 | Manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=manado
# City not found. Skipping...
# Processing Record 339 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=anadyr
# City not found. Skipping...
# Processing Record 340 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=la%20ronge
# Processing Record 341 | Ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ola
# Processing Record 342 | Meadow Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=meadow%20lake
# Processing Record 343 | Barranca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=barranca
# Processing Record 344 | Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tazovskiy
# City not found. Skipping...
# Processing Record 345 | Athens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=athens
# City not found. Skipping...
# Processing Record 346 | Yongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yongan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 347 | El Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=el%20campo
# Processing Record 348 | Quang Ngai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=quang%20ngai
# Processing Record 349 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vestmanna
# Processing Record 350 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=palmer
# Processing Record 351 | Taseyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=taseyevo
# Processing Record 352 | Aksha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aksha
# Processing Record 353 | Ambovombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ambovombe
# Processing Record 354 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=codrington
# Processing Record 355 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=necochea
# Processing Record 356 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=shelburne
# Processing Record 357 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kununurra
# Processing Record 358 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hami
# Processing Record 359 | Grasse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=grasse
# Processing Record 360 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bambous%20virieux
# Processing Record 361 | Bima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bima
# City not found. Skipping...
# Processing Record 362 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=smithers
# City not found. Skipping...
# Processing Record 363 | Casa Nova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=casa%20nova
# Processing Record 364 | Morro Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=morro%20bay
# Processing Record 365 | Banamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=banamba
# Processing Record 366 | Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=doha
# City not found. Skipping...
# Processing Record 367 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=praia
# Processing Record 368 | Pocone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pocone
# Processing Record 369 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=koumac
# Processing Record 370 | Gillette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=gillette
# City not found. Skipping...
# Processing Record 371 | Inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=inuvik
# Processing Record 372 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint-pierre
# Processing Record 373 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=talnakh
# City not found. Skipping...
# Processing Record 374 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bandarbeyla
# City not found. Skipping...
# Processing Record 375 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sambava
# Processing Record 376 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=broome
# City not found. Skipping...
# Processing Record 377 | Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=porto%20walter
# Processing Record 378 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vanimo
# Processing Record 379 | Kumbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kumbo
# City not found. Skipping...
# Processing Record 380 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=olinda
# Processing Record 381 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pitimbu
# Processing Record 382 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=camacha
# Processing Record 383 | Yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yining
# Processing Record 384 | Chongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chongwe
# Processing Record 385 | Pitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pitea
# City not found. Skipping...
# Processing Record 386 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kutum
# Processing Record 387 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=coquimbo
# Processing Record 388 | Dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dharchula
# Processing Record 389 | Partizansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=partizansk
# Processing Record 390 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=rio%20gallegos
# Processing Record 391 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nemuro
# Processing Record 392 | Plouzane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=plouzane
# Processing Record 393 | Kutina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kutina
# Processing Record 394 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=comodoro%20rivadavia
# Processing Record 395 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=deputatskiy
# Processing Record 396 | Aracati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aracati
# Processing Record 397 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=chernyshevskiy
# Processing Record 398 | Springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=springbok
# Processing Record 399 | Straumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=straumen
# Processing Record 400 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hofn
# Processing Record 401 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=coihaique
# Processing Record 402 | Narasannapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=narasannapeta
# Processing Record 403 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=umm%20kaddadah
# Processing Record 404 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=fort%20nelson
# City not found. Skipping...
# Processing Record 405 | Guiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=guiyang
# Processing Record 406 | Maunabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=maunabo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 407 | Hanzhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hanzhong
# Processing Record 408 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lethem
# Processing Record 409 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=cockburn%20town
# Processing Record 410 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=zhangjiakou
# Processing Record 411 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dunedin
# Processing Record 412 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jalu
# Processing Record 413 | Lalmohan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lalmohan
# Processing Record 414 | Boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=boende
# Processing Record 415 | Kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kitimat
# Processing Record 416 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20blair
# Processing Record 417 | Karlskrona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=karlskrona
# Processing Record 418 | Lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lima
# Processing Record 419 | Saint-Louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint-louis
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 420 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tilichiki
# Processing Record 421 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=touros
# Processing Record 422 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=luanda
# City not found. Skipping...
# Processing Record 423 | Svecha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=svecha
# Processing Record 424 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=maragogi
# Processing Record 425 | Fort Frances
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=fort%20frances
# Processing Record 426 | Bakhmach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bakhmach
# Processing Record 427 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mehamn
# City not found. Skipping...
# Processing Record 428 | Morant Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=morant%20bay
# Processing Record 429 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kahului
# Processing Record 430 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=zhigansk
# City not found. Skipping...
# Processing Record 431 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=trinidad
# Processing Record 432 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=arman
# Processing Record 433 | Paramonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=paramonga
# Processing Record 434 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=auki
# Processing Record 435 | Shira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=shira
# Processing Record 436 | Elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=elko
# Processing Record 437 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lagoa
# Processing Record 438 | Qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=qandala
# Processing Record 439 | Rincon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=rincon
# Processing Record 440 | Rorvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=rorvik
# Processing Record 441 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=axim
# Processing Record 442 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=aklavik
# Processing Record 443 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tucuman
# Processing Record 444 | Bojnurd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bojnurd
# Processing Record 445 | Dorogobuzh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dorogobuzh
# City not found. Skipping...
# Processing Record 446 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=okha
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 447 | Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=marsa%20matruh
# Processing Record 448 | Vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vaitape
# Processing Record 449 | Baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=baherden
# Processing Record 450 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=porto%20novo
# Processing Record 451 | Jamay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jamay
# Processing Record 452 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=huarmey
# Processing Record 453 | Beira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=beira
# Processing Record 454 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dingle
# Processing Record 455 | Matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=matay
# City not found. Skipping...
# Processing Record 456 | Watsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=watsa
# Processing Record 457 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=takoradi
# Processing Record 458 | Merrill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=merrill
# Processing Record 459 | Hengyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=hengyang
# Processing Record 460 | Lichuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=lichuan
# Processing Record 461 | Pahalgam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=pahalgam
# Processing Record 462 | Vetluga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=vetluga
# City not found. Skipping...
# Processing Record 463 | Muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=muroto
# Processing Record 464 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nuuk
# Processing Record 465 | Sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sawakin
# Processing Record 466 | Satna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=satna
# Processing Record 467 | Izumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=izumo
# Processing Record 468 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=solnechnyy
# Processing Record 469 | Bahadurgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bahadurgarh
# Processing Record 470 | Veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=veraval
# Processing Record 471 | Yucaipa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yucaipa
# Processing Record 472 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=dukat
# Processing Record 473 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=namatanai
# Processing Record 474 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yar-sale
# Processing Record 475 | Nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=nacala
# Processing Record 476 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=imbituba
# Processing Record 477 | Taft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=taft
# Processing Record 478 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=flinders
# Processing Record 479 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=inhambane
# City not found. Skipping...
# Processing Record 480 | Weinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=weinan
# Processing Record 481 | Yuncheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yuncheng
# Processing Record 482 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=san%20policarpo
# Processing Record 483 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=mana
# Processing Record 484 | Sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=sabang
# Processing Record 485 | Urusha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=urusha
# Processing Record 486 | Conceicao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=conceicao%20da%20barra
# Processing Record 487 | Kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kjollefjord
# Processing Record 488 | Borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=borogontsy
# Processing Record 489 | Barra do Garcas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=barra%20do%20garcas
# Processing Record 490 | Miandrivazo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=miandrivazo
# Processing Record 491 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=port%20macquarie
# Processing Record 492 | Kamakhyanagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kamakhyanagar
# Processing Record 493 | Macamic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=macamic
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 494 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=qasigiannguit
# Processing Record 495 | Ramhormoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=ramhormoz
# Processing Record 496 | Soavinandriana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=soavinandriana
# Processing Record 497 | Corredor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=corredor
# Processing Record 498 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=bud
# Processing Record 499 | Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=valley
# Processing Record 500 | Kyrylivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=kyrylivka
# Processing Record 501 | Tokmak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=tokmak
# Processing Record 502 | Jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=jinchang
# Processing Record 503 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=yumen
# Processing Record 504 | Niquero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=niquero
# Processing Record 505 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=saint-joseph
# Processing Record 506 | Berezovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=berezovyy
# Processing Record 507 | West Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=west%20bay
# Processing Record 508 | Torres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=torres
# Processing Record 509 | Presidencia Roque Saenz Pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=presidencia%20roque%20saenz%20pena
# City not found. Skipping...
# Processing Record 510 | Murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=murgab
# Processing Record 511 | Alghero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=&q=alghero
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create df 
weather_data = pd.DataFrame(weatherpy_dict)

# Display count
weather_data.count()
# Out:
# City          511
# Cloudiness    511
# Country       511
# Date          511
# Humidity      511
# Lat           511
# Lng           511
# Max Temp      511
# Wind Speed    511
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('weather_data.csv')
# sort by humidity and delete first two entries

# Display data frame head 
weather_data.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0  Ushuaia          75      AR  1561222686        86 -54.81  -68.31     33.80
# 1    Bluff          39      AU  1561222687        62 -23.58  149.07     55.47
# 2   Kodiak          75      US  1561222688        74  39.95  -94.76     80.01
# 3   Gympie           0      AU  1561222690        86 -26.20  152.66     48.99
# 4  Crotone           0      IT  1561222691        58  39.09   17.12     84.20
#
#    Wind Speed
# 0        6.93
# 1        4.25
# 2       16.11
# 3        1.01
# 4       12.75

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("MaxTemp_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Humidity_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Cloudiness_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("WindSpeed_v_Latitude.png")
plt.show()
